# %%
from Summary import process_and_plot_exp

# %% [markdown]
# #### EXP1

# %%
process_and_plot_exp(experiment_type="EXP1", config= "EXP1")

# %% [markdown]
# #### EXP2

# %%
from Summary import process_and_plot_exp
process_and_plot_exp(experiment_type="EXP2", config= "EXP2")
# Out:
# 🚀 Processing EXP2 with config EXP2...
# Initial NaN values in 'raw_answer': 0
# NaN values in 'raw_answer' after cleaning: 0
#
# 📄 File Processed: /hpcstor6/scratch01/h/huuthanhvy.nguyen001/EXP2/finetuning-EXP2numberone-test/EXP-Results/EXP2numberone_results.csv
#   ✅ Total Rows: 825
#   ✅ Valid Rows: 678
#   ❌ Invalid Rows: 147
# Processing dataset: pie
#   Remaining rows after cleanup: 678
# Processing dataset: bar
#   Remaining rows after cleanup: 0
#   ⚠️ Dataset bar has no valid rows. Skipping...

# %% [markdown]
# #### EXP3

# %%
process_and_plot_exp(experiment_type="EXP3", config= "EXP3")

# %% [markdown]
# #### EXP4

# %%
process_and_plot_exp(experiment_type="EXP4", config = "EXP4")
# Out:
# 🚀 Processing EXP4 with config EXP4...
# Initial NaN values in 'raw_answer': 0
# NaN values in 'raw_answer' after cleaning: 0
#
# 📄 File Processed: /hpcstor6/scratch01/h/huuthanhvy.nguyen001/EXP4/finetuning-EXP4numberone-test/EXP-Results/EXP4numberone_results.csv
#   ✅ Total Rows: 15
#   ✅ Valid Rows: 15
#   ❌ Invalid Rows: 0
# Processing dataset: framed
#   Remaining rows after cleanup: 15
# Processing dataset: unframed
#   Remaining rows after cleanup: 0
#   ⚠️ Dataset unframed has no valid rows. Skipping...

# %% [markdown]
# #### EXP5

# %%
process_and_plot_exp(experiment_type="EXP4", config = "EXP4")
