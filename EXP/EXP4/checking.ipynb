# %%
from EXP4fullprogress import generate_dataset_exp4

main_output_dir="./checkingoverlap"

images_per_task = 5000

generate_dataset_exp4(main_output_dir, images_per_task)
# Out:
# --- Generating images for task: framed ---
# Task framed generation completed with 14564 iterations.
#
# --- Generating images for task: unframed ---
# Task unframed generation completed with 14983 iterations.
# Saving train dataset. Example entry: {'id': '889656c6-fa4e-4b2c-a61d-d215aa0d2338', 'image': 'images/framed_889656c6-fa4e-4b2c-a61d-d215aa0d2338.jpg', 'task': 'framed', 'question': 'Estimate the lengths of the two bars with framing. Both lengths should fall between 49 and 60 pixels. No explanation. Format of the answer [xx, xx]', 'value': [49.0, 57.0]}
# Train dataset saved as 'train_dataset.json' in './checkingoverlap/json'
# Saving val dataset. Example entry: {'id': 'a7c515ca-59cd-4cb0-a639-615b28637cca', 'image': 'images/framed_a7c515ca-59cd-4cb0-a639-615b28637cca.jpg', 'task': 'framed', 'question': 'Estimate the lengths of the two bars with framing. Both lengths should fall between 49 and 60 pixels. No explanation. Format of the answer [xx, xx]', 'value': [50.0, 59.0]}
# ...

# %%
import os
import json
from EXP4fullprogress import display_training_samples_exp4, verify_dataset, verify_dataset_and_show_images

main_output_dir="./checkingoverlap"

display_training_samples_exp4(main_output_dir)

verify_dataset(main_output_dir)

verify_dataset_and_show_images(main_output_dir)
# Out:
# ...
# 📸 Displaying random images for 🔵 Training dataset:
# ...
#
# 📌 Task: FRAMED
# Displaying 2 random samples
# --------------------------------------------------
# 📌 Task: UNFRAMED
# Displaying 2 random samples
# --------------------------------------------------
# ...
#                DATASET SUMMARY
# ...
#
# 📊 Total Images per Dataset:
# ----------------------------------------
# 🔵 Training:    10,000 images
# 🟡 Validation:  2,000 images
# 🟢 Testing:     1,000 images
# 📈 Total:       13,000 images
#
# ...
#                TASK DISTRIBUTION
# ...
#
# | Dataset      | Task                   | Image Count |
# |------------|------------------------|-------------|
# | 🔵 Training | framed                 |        5000 |
# | 🔵 Training | unframed               |        5000 |
# | 🟡 Valid    | framed                 |        1000 |
# | 🟡 Valid    | unframed               |        1000 |
# | 🟢 Test     | framed                 |         500 |
# | 🟢 Test     | unframed               |         500 |
#
# ...
