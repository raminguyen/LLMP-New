# %%
from EXP3fullprogress import generate_dataset_exp3, verify_dataset

main_output_dir="./checkingoverlap"

images_per_task = 5000

generate_dataset_exp3(main_output_dir, images_per_task)

verify_dataset(main_output_dir)
# Out:
# --- Generating images for task: type1 ---
# Task type1 generation completed with 11721 iterations.
#
# --- Generating images for task: type2 ---
# Task type2 generation completed with 11901 iterations.
#
# --- Generating images for task: type3 ---
# Task type3 generation completed with 11724 iterations.
#
# --- Generating images for task: type4 ---
# Task type4 generation completed with 11719 iterations.
#
# --- Generating images for task: type5 ---
# Task type5 generation completed with 11562 iterations.
# Saving train dataset. Example entry: {'id': 'f73f373c-1623-4533-81d5-ffa2a4b3c308', 'image': 'images/type1_f73f373c-1623-4533-81d5-ffa2a4b3c308.jpg', 'task': 'type1', 'question': 'In the grouped bar chart, compare the heights of the two marked bars. Estimate the ratio of the height of the shorter marked bar to the height of the taller marked bar. Use a scale from 0 to 1, where 1 indicates that both marked bars are of equal height. No explaination.', 'value': 0.45454545454545453}
# Train dataset saved as 'train_dataset.json' in './checkingoverlap/json'
# Saving val dataset. Example entry: {'id': 'fbe562e5-726e-46d7-ae9a-760de442da5a', 'image': 'images/type1_fbe562e5-726e-46d7-ae9a-760de442da5a.jpg', 'task': 'type1', 'question': 'In the grouped bar chart, compare the heights of the two marked bars. Estimate the ratio of the height of the shorter marked bar to the height of the taller marked bar. Use a scale from 0 to 1, where 1 indicates that both marked bars are of equal height. No explaination.', 'value': 0.2631578947368421}
# Val dataset saved as 'val_dataset.json' in './checkingoverlap/json'
# Saving test dataset. Example entry: {'id': 'a1c36681-34e6-4b37-867f-79b81786d776', 'image': 'images/type1_a1c36681-34e6-4b37-867f-79b81786d776.jpg', 'task': 'type1', 'question': 'In the grouped bar chart, compare the heights of the two marked bars. Estimate the ratio of the height of the shorter marked bar to the height of the taller marked bar. Use a scale from 0 to 1, where 1 indicates that both marked bars are of equal height. No explaination.', 'value': 0.6923076923076923}
# Test dataset saved as 'test_dataset.json' in './checkingoverlap/json'
# Saving train dataset. Example entry: {'id': 'f73f373c-1623-4533-81d5-ffa2a4b3c308', 'image': 'images/type1_f73f373c-1623-4533-81d5-ffa2a4b3c308.jpg', 'task': 'type1', 'question': 'In the grouped bar chart, compare the heights of the two marked bars. Estimate the ratio of the height of the shorter marked bar to the height of the taller marked bar. Use a scale from 0 to 1, where 1 indicates that both marked bars are of equal height. No explaination.', 'value': 0.45454545454545453}
# Train dataset saved as 'train_dataset.json' in './checkingoverlap/json'
# Saving val dataset. Example entry: {'id': 'fbe562e5-726e-46d7-ae9a-760de442da5a', 'image': 'images/type1_fbe562e5-726e-46d7-ae9a-760de442da5a.jpg', 'task': 'type1', 'question': 'In the grouped bar chart, compare the heights of the two marked bars. Estimate the ratio of the height of the shorter marked bar to the height of the taller marked bar. Use a scale from 0 to 1, where 1 indicates that both marked bars are of equal height. No explaination.', 'value': 0.2631578947368421}
# Val dataset saved as 'val_dataset.json' in './checkingoverlap/json'
# Saving test dataset. Example entry: {'id': 'a1c36681-34e6-4b37-867f-79b81786d776', 'image': 'images/type1_a1c36681-34e6-4b37-867f-79b81786d776.jpg', 'task': 'type1', 'question': 'In the grouped bar chart, compare the heights of the two marked bars. Estimate the ratio of the height of the shorter marked bar to the height of the taller marked bar. Use a scale from 0 to 1, where 1 indicates that both marked bars are of equal height. No explaination.', 'value': 0.6923076923076923}
# Test dataset saved as 'test_dataset.json' in './checkingoverlap/json'
#
# ==================================================
#                DATASET SUMMARY
# ==================================================
#
# 📊 Total Images per Dataset:
# ----------------------------------------
# 🔵 Training:    25,000 images
# 🟡 Validation:  5,000 images
# 🟢 Testing:     2,500 images
# 📈 Total:       32,500 images
#
# ==================================================
#                TASK DISTRIBUTION
# ==================================================
#
# | Dataset      | Task                   | Image Count |
# |------------|------------------------|-------------|
# | 🔵 Training | type1                  |        5000 |
# | 🔵 Training | type2                  |        5000 |
# | 🔵 Training | type3                  |        5000 |
# | 🔵 Training | type4                  |        5000 |
# | 🔵 Training | type5                  |        5000 |
# | 🟡 Valid    | type1                  |        1000 |
# | 🟡 Valid    | type2                  |        1000 |
# | 🟡 Valid    | type3                  |        1000 |
# | 🟡 Valid    | type4                  |        1000 |
# | 🟡 Valid    | type5                  |        1000 |
# | 🟢 Test     | type1                  |         500 |
# | 🟢 Test     | type2                  |         500 |
# | 🟢 Test     | type3                  |         500 |
# | 🟢 Test     | type4                  |         500 |
# | 🟢 Test     | type5                  |         500 |
#
# ==================================================
#                OVERLAP ANALYSIS
# ==================================================
# ✅ No overlap between Training and Validation
# ✅ No overlap between Training and Testing
# ✅ No overlap between Validation and Testing
#
# ==================================================
#                UNIQUE LABELS
# ==================================================
#
# | Dataset      | Total Unique Labels |
# |------------|-------------------|
# | 🔵 Training |                16 |
# | 🟡 Valid    |                12 |
# | 🟢 Test     |                10 |
#
# ==================================================
