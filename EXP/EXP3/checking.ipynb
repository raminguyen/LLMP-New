# %%
from EXP3fullprogress import generate_dataset_exp3, verify_dataset

main_output_dir="./checkingoverlap"

images_per_task = 5000

generate_dataset_exp3(main_output_dir, images_per_task)

verify_dataset(main_output_dir)
# Out:
# --- Generating images for task: type1 ---
# Task type1 generation completed with 13727 iterations.
#
# --- Generating images for task: type2 ---
# Task type2 generation completed with 13872 iterations.
#
# --- Generating images for task: type3 ---
# Task type3 generation completed with 13581 iterations.
#
# --- Generating images for task: type4 ---
# Task type4 generation completed with 13972 iterations.
#
# --- Generating images for task: type5 ---
# Task type5 generation completed with 13943 iterations.
# Saving train dataset. Example entry: {'id': '53f32964-b79e-4d75-8eef-7c28f708cb65', 'image': 'images/type1_53f32964-b79e-4d75-8eef-7c28f708cb65.jpg', 'task': 'type1', 'question': 'In the grouped bar chart, compare the heights of the two marked bars. Estimate the ratio of the height of the shorter marked bar to the height of the taller marked bar. Use a scale from 0 to 1, where 1 indicates that both marked bars are of equal height. No explaination.', 'value': 0.46153846153846156}
# ...

# %%
from EXP3fullprogress import verify_dataset_and_show_images

verify_dataset_and_show_images(main_output_dir)
# Out:
# ...
# Overlapping Images Across Datasets
# ...
#
# Overlapping Label: 0.46153846153846156
#
# Displaying images for Overlapping Label: 0.46153846153846156
#
# Task: images/type1
# Skipping Task: images/type1 (Not enough images from all datasets)
#
# Task: images/type2
# Skipping Task: images/type2 (Not enough images from all datasets)
#
# Task: images/type3
# Skipping Task: images/type3 (Not enough images from all datasets)
#
# Task: images/type4
# Skipping Task: images/type4 (Not enough images from all datasets)
#
# Task: images/type5
# Skipping Task: images/type5 (Not enough images from all datasets)
#
# Overlapping Label: 0.32142857142857145
#
# Displaying images for Overlapping Label: 0.32142857142857145
#
# Task: images/type1
# Skipping Task: images/type1 (Not enough images from all datasets)
#
# Task: images/type2
# Skipping Task: images/type2 (Not enough images from all datasets)
#
# Task: images/type3
# Skipping Task: images/type3 (Not enough images from all datasets)
#
# ...
